# %% [markdown]
# #1. File Upload

# %%
from google.colab import files
upload_file = files.upload()
# Out:
#      <input type="file" id="files-e6fa9829-0a85-4751-b775-b374904a016a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e6fa9829-0a85-4751-b775-b374904a016a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car1.jpg to car1 (1).jpg

# %% [markdown]
# #2. Load File

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# !ls -al
# Out:
# total 364
# drwxr-xr-x 1 root root   4096 Jun  2 06:41  .
# drwxr-xr-x 1 root root   4096 Jun  2 05:35  ..
# -rw-r--r-- 1 root root  77963 Jun  2 06:41 'car1 (1).jpg'
# -rw-r--r-- 1 root root  77963 Jun  2 05:36  car1.jpg
# -rw-r--r-- 1 root root 189079 Jun  2 05:58  car_copy.jpg
# drwxr-xr-x 4 root root   4096 May  6 13:43  .config
# drwxr-xr-x 1 root root   4096 May  6 13:44  sample_data

# %%
img = cv2.imread('car1.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F8117623D10>

# %%
print("width: {} pixels".format(img.shape[1]))
print("Height: {} pixels".format(img.shape[0]))
print("Channels: {}".format(img.shape[2]))
# Out:
# width: 1280 pixels
# Height: 720 pixels
# Channels: 3

# %%
X = 247 #@param {type:"slider", min:0, max:1280, step:1}
Y = 354 #@param {type:"slider", min:0, max:720, step:1}
SIZE = 100 #@param {type:"slider", min:0, max:200, step:1}

# %%
(b,g,r) = img[X, Y]
print("Pixel at ({}, {}) - Red: {}, Green: {}, Blue: {}".format(X, Y, r, g, b))
# Out:
# Pixel at (247, 354) - Red: 65, Green: 82, Blue: 64

# %%
# crop coordination = image[y:y+h, x:x+w]
crop = img[Y:Y+SIZE, X:X+SIZE]
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7F811C618350>

# %%
img[Y:Y+SIZE, X:X+SIZE] = (0, 0, 255)

# %%
cv2.rectangle(img, (X+SIZE*2, Y), (X+SIZE*3, Y+SIZE), (0, 255, 0), 5)

# %%
radius = int(SIZE/2)
cv2.circle(img, (X+SIZE*4, Y+radius), radius, (255,255,0), -1)

# %%
cv2.line(img, (X+SIZE*5, Y), (X+SIZE*6, Y+SIZE), (0, 255, 255), 5)

# %%
cv2.putText(img, 'Apple', (X+SIZE*7, Y+SIZE), cv2.FONT_HERSHEY_COMPLEX, 1, (255,0,0))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F81175BBD10>

# %%
cv2.imwrite('car1_copy.jpg', img)
# Out:
# True

# %%
# !ls -al
# Out:
# total 536
# drwxr-xr-x 1 root root   4096 Jun  2 06:43  .
# drwxr-xr-x 1 root root   4096 Jun  2 05:35  ..
# -rw-r--r-- 1 root root  77963 Jun  2 06:41 'car1 (1).jpg'
# -rw-r--r-- 1 root root 184286 Jun  2 06:43  car1_copy.jpg
# -rw-r--r-- 1 root root  77963 Jun  2 05:36  car1.jpg
# -rw-r--r-- 1 root root 184286 Jun  2 06:43  car_copy.jpg
# drwxr-xr-x 4 root root   4096 May  6 13:43  .config
# drwxr-xr-x 1 root root   4096 May  6 13:44  sample_data

# %%
def download(path):
  try:
    from google.colab import files
    files.download(path)
  except ImportError:
    import os
    print('Download Error: ', os.path.join(os, getcwd(), path))

# %%
download('car_copy.jpg')
