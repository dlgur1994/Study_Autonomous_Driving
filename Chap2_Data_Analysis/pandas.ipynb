# %% [markdown]
# #1. Mount Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# !ls -al '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data'
# Out:
# total 1405273
# -rw------- 1 root root    337847 May 20 07:49 TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202001
# -rw------- 1 root root    337847 May 20 07:50 TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202001.csv
# -rw------- 1 root root 699429059 May 20 05:49 TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202002
# -rw------- 1 root root    337847 May 20 07:54 TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202002.csv
# -rw------- 1 root root 738556069 May 20 05:49 TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202003

# %% [markdown]
# #2. Load Data

# %%
import pandas as pd

# %%
# Load a file under "data" folder
file = '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/TCS_%EC%98%81%EC%97%85%EC%86%8C%EA%B0%84%ED%86%B5%ED%96%89%EC%8B%9C%EA%B0%84_1%EC%8B%9C%EA%B0%84_1%EA%B0%9C%EC%9B%94_202001'
data = pd.read_csv(file, sep=',', encoding="euc-kr")

# %%
data.head()
# Out:
#        집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간  Unnamed: 6
# 0  20200101   17        0      101          3    -1         NaN
# 1  20200101   17        0      101          1    -1         NaN
# 2  20200101    9        0      101          2    -1         NaN
# 3  20200101    9        0      101          1    -1         NaN
# 4  20200101    7        0      101          1    -1         NaN

# %%
data.tail()
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드   통행시간  Unnamed: 6
# 25596211  20200131    9      272      641          1   8388         NaN
# 25596212  20200131   15      137      245          3   2341         NaN
# 25596213  20200131    6      127      612          5  42535         NaN
# 25596214  20200131    6      671      127          1   9494         NaN
# 25596215  20200131   17      212      253          3    833         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25596216 entries, 0 to 25596215
# Data columns (total 7 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   집계일자        int64
#  1   집계시         int64
#  2   출발영업소코드     int64
#  3   도착영업소코드     int64
#  4   TCS차종구분코드   int64
#  5   통행시간        int64
#  6   Unnamed: 6  float64
# dtypes: float64(1), int64(6)
# memory usage: 1.3 GB

# %% [markdown]
# #3. Clean Data

# %%
# check the null values in the data fields
data.isnull().sum(axis=0)
# Out:
# 집계일자                 0
# 집계시                  0
# 출발영업소코드              0
# 도착영업소코드              0
# TCS차종구분코드            0
# 통행시간                 0
# Unnamed: 6    25596216
# dtype: int64

# %%
# show columns of the data frame
data.columns
# Out:
# Index(['집계일자', '집계시', '출발영업소코드', '도착영업소코드', 'TCS차종구분코드', '통행시간', 'Unnamed: 6'], dtype='object')

# %%
# select by '.' operator
data.집계일자
# Out:
# 0           20200101
# 1           20200101
# 2           20200101
# 3           20200101
# 4           20200101
#               ...
# 25596211    20200131
# 25596212    20200131
# 25596213    20200131
# 25596214    20200131
# 25596215    20200131
# Name: 집계일자, Length: 25596216, dtype: int64

# %%
# select by '[]' operator
data['집계일자']
# Out:
# 0           20200101
# 1           20200101
# 2           20200101
# 3           20200101
# 4           20200101
#               ...
# 25596211    20200131
# 25596212    20200131
# 25596213    20200131
# 25596214    20200131
# 25596215    20200131
# Name: 집계일자, Length: 25596216, dtype: int64

# %%
# select by '[]' operator
data['Unnamed: 6']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#             ..
# 25596211   NaN
# 25596212   NaN
# 25596213   NaN
# 25596214   NaN
# 25596215   NaN
# Name: Unnamed: 6, Length: 25596216, dtype: float64

# %%
# drop some columns with null values
data_clean = data.drop(['Unnamed: 6'], axis='columns')

# %%
data_clean.head()
# Out:
#        집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간
# 0  20200101   17        0      101          3    -1
# 1  20200101   17        0      101          1    -1
# 2  20200101    9        0      101          2    -1
# 3  20200101    9        0      101          1    -1
# 4  20200101    7        0      101          1    -1

# %%
(data_clean.통행시간 > 0).unique()
# Out:
# array([False,  True])

# %%
data_clean = data_clean[data_clean.통행시간 > 0]

# %%
data_clean.head()
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간
# 5853  20200101   22      101      102          6   632
# 5854  20200101   22      101      102          3   633
# 5855  20200101   16      101      102          6   650
# 5856  20200101   16      101      102          1   623
# 5857  20200101   16      101      102          3   626

# %%
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21531295 entries, 5853 to 25596215
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   집계일자       int64
#  1   집계시        int64
#  2   출발영업소코드    int64
#  3   도착영업소코드    int64
#  4   TCS차종구분코드  int64
#  5   통행시간       int64
# dtypes: int64(6)
# memory usage: 1.1 GB

# %% [markdown]
# #4. Select Data

# %%
data_clean.head()
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간
# 5853  20200101   22      101      102          6   632
# 5854  20200101   22      101      102          3   633
# 5855  20200101   16      101      102          6   650
# 5856  20200101   16      101      102          1   623
# 5857  20200101   16      101      102          3   626

# %%
data_clean[0:5]
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  TCS차종구분코드  통행시간
# 5853  20200101   22      101      102          6   632
# 5854  20200101   22      101      102          3   633
# 5855  20200101   16      101      102          6   650
# 5856  20200101   16      101      102          1   623
# 5857  20200101   16      101      102          3   626

# %%
df_data = pd.DataFrame(data_clean, columns=['집계일자', '집계시', '출발영업소코드', '도착영업소코드', '통행시간'])

# %%
df_data.head()
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  통행시간
# 5853  20200101   22      101      102   632
# 5854  20200101   22      101      102   633
# 5855  20200101   16      101      102   650
# 5856  20200101   16      101      102   623
# 5857  20200101   16      101      102   626

# %%
long_distance = df_data.통행시간 > 700

# %%
long_distance
# Out:
# 5853        False
# 5854        False
# 5855        False
# 5856        False
# 5857        False
#             ...
# 25596211     True
# 25596212     True
# 25596213     True
# 25596214     True
# 25596215     True
# Name: 통행시간, Length: 21531295, dtype: bool

# %%
start_from_101 = df_data[df_data.출발영업소코드 == 101]

# %%
start_from_101
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간
# 5853      20200101   22      101      102    632
# 5854      20200101   22      101      102    633
# 5855      20200101   16      101      102    650
# 5856      20200101   16      101      102    623
# 5857      20200101   16      101      102    626
# ...            ...  ...      ...      ...    ...
# 25595893  20200131    8      101      596  28576
# 25595991  20200131   17      101      698  16752
# 25596003  20200131   15      101      705   2587
# 25596023  20200131    1      101      175   1769
# 25596210  20200131    4      101      601   3202
#
# [269409 rows x 5 columns]

# %%
# 101 서울, 105 기흥, 110 목천, 115 대전, 120 황간, 125 남구미, 130 동김천, 135 경주, 140 부산
start_from_101_to_140 = start_from_101[start_from_101['도착영업소코드'].isin([105, 110, 115, 120, 125, 130, 135, 140])]

# %%
start_from_101_to_140
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간
# 6079      20200101    4      101      105    637
# 6080      20200101    4      101      105    773
# 6081      20200101    4      101      105    762
# 6082      20200101    4      101      105    746
# 6083      20200101    4      101      105    875
# ...            ...  ...      ...      ...    ...
# 25574957  20200131   10      101      125   7776
# 25575802  20200131    2      101      140  14189
# 25584233  20200131    4      101      110   3780
# 25586486  20200131   15      101      120   8269
# 25595750  20200131   18      101      130   9769
#
# [12749 rows x 5 columns]

# %%
start_from_101_to_140.value_counts()
# Out:
# 집계일자      집계시  출발영업소코드  도착영업소코드  통행시간
# 20200116  14   101      110      3546    2
# 20200104  3    101      105      770     2
# 20200106  8    101      105      976     2
# 20200124  14   101      105      845     2
# 20200120  10   101      105      877     2
#                                         ..
# 20200121  5    101      105      788     1
#                                  729     1
#                                  651     1
#                                  629     1
# 20200101  0    101      105      616     1
# Length: 12717, dtype: int64

# %% [markdown]
# #5. Convert & Insert Data
#
# The days are numbered from 0 to 6 when 0 is Monday and 6 is Sunday.

# %%
# 1: By declaring a new list as a column
start_from_101_to_140['요일'] = pd.to_datetime(start_from_101_to_140['집계일자'], format='%Y%m%d').dt.dayofweek
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
start_from_101_to_140
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간  요일
# 6079      20200101    4      101      105    637   2
# 6080      20200101    4      101      105    773   2
# 6081      20200101    4      101      105    762   2
# 6082      20200101    4      101      105    746   2
# 6083      20200101    4      101      105    875   2
# ...            ...  ...      ...      ...    ...  ..
# 25574957  20200131   10      101      125   7776   4
# 25575802  20200131    2      101      140  14189   4
# 25584233  20200131    4      101      110   3780   4
# 25586486  20200131   15      101      120   8269   4
# 25595750  20200131   18      101      130   9769   4
#
# [12749 rows x 6 columns]

# %%
# 2: Using .loc[]
start_from_101_to_140.loc[:, '요일'] = pd.to_datetime(start_from_101_to_140['집계일자'], format='%Y%m%d').dt.dayofweek
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
start_from_101_to_140.head()
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  통행시간  요일
# 6079  20200101    4      101      105   637   2
# 6080  20200101    4      101      105   773   2
# 6081  20200101    4      101      105   762   2
# 6082  20200101    4      101      105   746   2
# 6083  20200101    4      101      105   875   2

# %%
# 3: Using the .assign() function
start_from_101_to_140 = start_from_101_to_140.assign(요일=pd.to_datetime(start_from_101_to_140['집계일자'], format='%Y%m%d').dt.dayofweek)

# %%
start_from_101_to_140
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간  요일
# 6079      20200101    4      101      105    637   2
# 6080      20200101    4      101      105    773   2
# 6081      20200101    4      101      105    762   2
# 6082      20200101    4      101      105    746   2
# 6083      20200101    4      101      105    875   2
# ...            ...  ...      ...      ...    ...  ..
# 25574957  20200131   10      101      125   7776   4
# 25575802  20200131    2      101      140  14189   4
# 25584233  20200131    4      101      110   3780   4
# 25586486  20200131   15      101      120   8269   4
# 25595750  20200131   18      101      130   9769   4
#
# [12749 rows x 6 columns]

# %%
start_from_101_to_140.dtypes
# Out:
# 집계일자       int64
# 집계시        int64
# 출발영업소코드    int64
# 도착영업소코드    int64
# 통행시간       int64
# 요일         int64
# dtype: object

# %% [markdown]
# #6. Sort & Group Data

# %%
start_from_101_to_140.sort_values(by=['통행시간'])
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간  요일
# 11369088  20200115    1      101      105    582   2
# 11380549  20200115    0      101      105    585   2
# 21183117  20200127    4      101      105    588   0
# 11369401  20200115    2      101      105    588   2
# 1101582   20200103    2      101      105    589   4
# ...            ...  ...      ...      ...    ...  ..
# 21899512  20200128    0      101      135  41632   1
# 13006907  20200117    8      101      130  41696   4
# 17933952  20200124    7      101      140  41960   4
# 12959275  20200117    7      101      130  46925   4
# 11851093  20200117    6      101      130  50001   4
#
# [12749 rows x 6 columns]

# %%
start_from_101_to_140.sort_values(by=['통행시간'], ascending=False)
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간  요일
# 11851093  20200117    6      101      130  50001   4
# 12959275  20200117    7      101      130  46925   4
# 17933952  20200124    7      101      140  41960   4
# 13006907  20200117    8      101      130  41696   4
# 21899512  20200128    0      101      135  41632   1
# ...            ...  ...      ...      ...    ...  ..
# 17024590  20200123    3      101      105    589   3
# 11369401  20200115    2      101      105    588   2
# 21183117  20200127    4      101      105    588   0
# 11380549  20200115    0      101      105    585   2
# 11369088  20200115    1      101      105    582   2
#
# [12749 rows x 6 columns]

# %%
start_from_101_to_140.sort_values(by=['집계일자', '집계시'], ascending=False)
# Out:
#               집계일자  집계시  출발영업소코드  도착영업소코드   통행시간  요일
# 24690951  20200131   23      101      105    871   4
# 24690952  20200131   23      101      105    857   4
# 24690953  20200131   23      101      105    736   4
# 24690954  20200131   23      101      105    768   4
# 24690955  20200131   23      101      105    916   4
# ...            ...  ...      ...      ...    ...  ..
# 6599      20200101    0      101      110   3319   2
# 6600      20200101    0      101      110   3263   2
# 6825      20200101    0      101      115   5718   2
# 6826      20200101    0      101      115   9284   2
# 7271      20200101    0      101      135  13637   2
#
# [12749 rows x 6 columns]

# %%
start_from_101_to_140.groupby(start_from_101_to_140['도착영업소코드']).mean()
# Out:
#                  집계일자        집계시  출발영업소코드          통행시간        요일
# 도착영업소코드
# 105      2.020012e+07  11.392094    101.0    872.217530  2.911613
# 110      2.020012e+07  11.509942    101.0   3605.229955  2.837075
# 115      2.020012e+07  11.802409    101.0   5826.651204  2.982159
# 120      2.020012e+07  12.654275    101.0   8498.178439  3.243494
# 125      2.020012e+07  12.976471    101.0   9688.117647  2.934454
# 130      2.020012e+07  12.795115    101.0   9661.925373  2.989145
# 135      2.020012e+07  12.317391    101.0  13859.042029  3.113043
# 140      2.020012e+07  12.136243    101.0  16407.931217  3.010582

# %%
start_from_101_to_140['통행시간'].groupby(start_from_101_to_140['도착영업소코드']).mean()
# Out:
# 도착영업소코드
# 105      872.217530
# 110     3605.229955
# 115     5826.651204
# 120     8498.178439
# 125     9688.117647
# 130     9661.925373
# 135    13859.042029
# 140    16407.931217
# Name: 통행시간, dtype: float64

# %%
groupby_destination = start_from_101_to_140['통행시간'].groupby(start_from_101_to_140['도착영업소코드'])

# %%
groupby_destination.size()
# Out:
# 도착영업소코드
# 105    4073
# 110    3118
# 115    2242
# 120     538
# 125     595
# 130     737
# 135     690
# 140     756
# Name: 통행시간, dtype: int64

# %%
groupby_destination.sum()
# Out:
# 도착영업소코드
# 105     3552542
# 110    11241107
# 115    13063352
# 120     4572020
# 125     5764430
# 130     7120839
# 135     9562739
# 140    12404396
# Name: 통행시간, dtype: int64

# %%
groupby_destination.mean()
# Out:
# 도착영업소코드
# 105      872.217530
# 110     3605.229955
# 115     5826.651204
# 120     8498.178439
# 125     9688.117647
# 130     9661.925373
# 135    13859.042029
# 140    16407.931217
# Name: 통행시간, dtype: float64

# %%
groupby_destination.max()
# Out:
# 도착영업소코드
# 105     2609
# 110     9940
# 115    14695
# 120    28954
# 125    21484
# 130    50001
# 135    41632
# 140    41960
# Name: 통행시간, dtype: int64

# %%
groupby_destination.min()
# Out:
# 도착영업소코드
# 105      582
# 110     2082
# 115     4123
# 120     5619
# 125     6904
# 130     6645
# 135     9492
# 140    12340
# Name: 통행시간, dtype: int64

# %% [markdown]
# #7. Save Data

# %%
output = '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202001.csv'
start_from_101_to_140.to_csv(output, index=None, header=True)

# %%
# !ls -al '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202001.csv'
# Out:
# -rw------- 1 root root 337847 May 20 08:04 '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202001.csv'

# %% [markdown]
# #8. Merge Data

# %%
data_202001 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202001.csv')
data_202002 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202002.csv')
data_202003 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_202003.csv')

# %%
data_2020 = pd.concat([data_202001, data_202002, data_202003], ignore_index=True, sort=False)

# %%
data_2020.head()
# Out:
#        집계일자  집계시  출발영업소코드  도착영업소코드  통행시간  요일
# 0  20200101    4      101      105   637   2
# 1  20200101    4      101      105   773   2
# 2  20200101    4      101      105   762   2
# 3  20200101    4      101      105   746   2
# 4  20200101    4      101      105   875   2

# %%
data_2020_by_time = pd.concat([data_202001, data_202002, data_202003], ignore_index=True, sort=False).set_index("통행시간")

# %%
data_2020_by_time.head()
# Out:
#           집계일자  집계시  출발영업소코드  도착영업소코드  요일
# 통행시간
# 637   20200101    4      101      105   2
# 773   20200101    4      101      105   2
# 762   20200101    4      101      105   2
# 746   20200101    4      101      105   2
# 875   20200101    4      101      105   2

# %%
final = '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_2020.csv'
data_2020.to_csv(final, index=None, header=True)

# %%
# !ls -al '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_2020.csv'
# Out:
# -rw------- 1 root root 988308 May 20 08:10 '/gdrive/My Drive/Colab Notebooks/자율주행_스터디/Chap2_데이터분석기초/data/data_2020.csv'
