# %% [markdown]
# #1. OpenAPI
#
# 실시간 영업소간 통행시간
#
# http://data.ex.co.kr/openapi/basicinfo/openApiInfoM?apiId=0147&serviceType=&keyWord=&searchDayFrom=2014.12.01&searchDayTo=2021.05.18&CATEGORY=TR&GROUP_TR=TIME_TCS

# %%
import requests

# %%
key = "1222267686"
type = "json"
StartUnitCode = "101"
EndUnitCode = "103"

URL = "http://data.ex.co.kr/openapi/trtm/realUnitTrtm?key="
url = URL + key + "&type=json&iStartUnitCode=" + StartUnitCode + "&iEndUnitCode=" + EndUnitCode

# %%
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
json = response.json()

# %%
json
# Out:
# {'code': 'SUCCESS',
#  'count': 601,
#  'message': '인증키가 유효합니다.',
#  'numOfRows': 10,
#  'pageNo': 1,
#  'pageSize': 61,
#  'realUnitTrtmVO': [{'efcvTrfl': '224',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00  ',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.533333333333333',
#    'timeMax': '10.550',
#    'timeMin': '5.750'},
#   {'efcvTrfl': '95',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:00',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.8',
#    'timeMax': '10.216',
#    'timeMin': '5.866'},
#   {'efcvTrfl': '22',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:05',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.85',
#    'timeMax': '9.850',
#    'timeMin': '6.083'},
#   {'efcvTrfl': '21',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:10',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.833333333333333',
#    'timeMax': '10.050',
#    'timeMin': '6.033'},
#   {'efcvTrfl': '77',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:15',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.716666666666667',
#    'timeMax': '9.716',
#    'timeMin': '5.950'},
#   {'efcvTrfl': '19',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:20',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.533333333333333',
#    'timeMax': '8.533',
#    'timeMin': '6.050'},
#   {'efcvTrfl': '16',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:25',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.616666666666666',
#    'timeMax': '9.716',
#    'timeMin': '6.350'},
#   {'efcvTrfl': '71',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:30',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.575',
#    'timeMax': '9.816',
#    'timeMin': '5.750'},
#   {'efcvTrfl': '14',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:35',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.5',
#    'timeMax': '8.983',
#    'timeMin': '6.283'},
#   {'efcvTrfl': '15',
#    'endUnitCode': '103 ',
#    'endUnitNm': '수원신갈',
#    'iEndUnitCode': None,
#    'iStartEndStdTypeCode': None,
#    'iStartUnitCode': None,
#    'numOfRows': None,
#    'pageNo': None,
#    'startEndStdTypeCode': '2',
#    'startEndStdTypeNm': '도착기준통행시간',
#    'startUnitCode': '101 ',
#    'startUnitNm': '서울',
#    'stdDate': '20210615',
#    'stdTime': '00:40',
#    'sumTmUnitTypeCode': None,
#    'tcsCarTypeCode': '1',
#    'tcsCarTypeDivCode': '1',
#    'tcsCarTypeDivName': '소형차',
#    'tcsCarTypeName': '1종',
#    'timeAvg': '7.583333333333333',
#    'timeMax': '9.816',
#    'timeMin': '6.366'}]}

# %%
cars = json["realUnitTrtmVO"]

# %%
cars
# Out:
# [{'efcvTrfl': '224',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00  ',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.533333333333333',
#   'timeMax': '10.550',
#   'timeMin': '5.750'},
#  {'efcvTrfl': '95',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:00',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.8',
#   'timeMax': '10.216',
#   'timeMin': '5.866'},
#  {'efcvTrfl': '22',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:05',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.85',
#   'timeMax': '9.850',
#   'timeMin': '6.083'},
#  {'efcvTrfl': '21',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:10',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.833333333333333',
#   'timeMax': '10.050',
#   'timeMin': '6.033'},
#  {'efcvTrfl': '77',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:15',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.716666666666667',
#   'timeMax': '9.716',
#   'timeMin': '5.950'},
#  {'efcvTrfl': '19',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:20',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.533333333333333',
#   'timeMax': '8.533',
#   'timeMin': '6.050'},
#  {'efcvTrfl': '16',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:25',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.616666666666666',
#   'timeMax': '9.716',
#   'timeMin': '6.350'},
#  {'efcvTrfl': '71',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:30',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.575',
#   'timeMax': '9.816',
#   'timeMin': '5.750'},
#  {'efcvTrfl': '14',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:35',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.5',
#   'timeMax': '8.983',
#   'timeMin': '6.283'},
#  {'efcvTrfl': '15',
#   'endUnitCode': '103 ',
#   'endUnitNm': '수원신갈',
#   'iEndUnitCode': None,
#   'iStartEndStdTypeCode': None,
#   'iStartUnitCode': None,
#   'numOfRows': None,
#   'pageNo': None,
#   'startEndStdTypeCode': '2',
#   'startEndStdTypeNm': '도착기준통행시간',
#   'startUnitCode': '101 ',
#   'startUnitNm': '서울',
#   'stdDate': '20210615',
#   'stdTime': '00:40',
#   'sumTmUnitTypeCode': None,
#   'tcsCarTypeCode': '1',
#   'tcsCarTypeDivCode': '1',
#   'tcsCarTypeDivName': '소형차',
#   'tcsCarTypeName': '1종',
#   'timeAvg': '7.583333333333333',
#   'timeMax': '9.816',
#   'timeMin': '6.366'}]

# %%
records = []
for car in cars:
  dic = {}
  dic["date"] = car["stdDate"]
  dic["time"] = car["stdTime"]
  dic["type"] = car["tcsCarTypeDivName"]
  records.append(dic)

records
# Out:
# [{'date': '20210615', 'time': '00  ', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:00', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:05', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:10', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:15', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:20', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:25', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:30', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:35', 'type': '소형차'},
#  {'date': '20210615', 'time': '00:40', 'type': '소형차'}]
